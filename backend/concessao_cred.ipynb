# %%
import pandas as pd
import numpy as np
import joblib

model = joblib.load("Project_Credit/modelo_credito.pkl")

# %% [markdown]
# ### Carregar dados do cliente

# %%
novo_cliente = pd.DataFrame([{
    "person_age": 30,
    "person_income": 20000,
    "person_emp_length": 5,
    "loan_amnt": 10000,
    "loan_int_rate": 12.5,
    "loan_percent_income": 0.2,
    "cb_person_cred_hist_length": 10,
    "cb_person_default_on_file": 0
}])

# %% [markdown]
# ### Classificação de risco + Predição

# %%
# quanto maior o risco, menor a nota do empréstimo

def model_loangrade(risk):
    if risk < 3:
        return """A"""
    elif risk < 6:
        return """B"""              
    elif risk < 12:
        return """C"""
    elif risk < 25:
        return """D"""
    elif risk < 50:
        return """E"""
    elif risk < 75:
        return """F"""
    else:
        return """G"""

# Predição de risco para o novo cliente

risk = model.predict_proba(novo_cliente)[0][1] * 100
print(model.predict(novo_cliente))
# Out:
# [0]

# %% [markdown]
# ### Resultado

# %%
print(f"Risco de inadimplência: {risk:.2f}%")
print(f"Nota de crédito: {model_loangrade(risk)}")
# Out:
# Risco de inadimplência: 16.91%
# Nota de crédito: D.
